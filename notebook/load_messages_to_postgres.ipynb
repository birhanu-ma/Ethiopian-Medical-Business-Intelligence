# %%
import os
import sys
# Step 1 — Go up one level (from /notebooks/bank_reviews → project_root)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)


# 2. Import your class from the .py file
from medical_warehouse.Scripts.load_to_postgres import TelegramDataLoader
import os
from app.core.config import settings

# %%
# 1. Initialize
loader = TelegramDataLoader()

# 2. Execute 
# The loader automatically pulls paths and table names from config.py
loader.run_pipeline()
# Out:
# 2026-02-17 15:41:31,811 - INFO - 💎 Database 'medical_warehouse' exists.
# 2026-02-17 15:41:31,814 - INFO - Loader initialized for database: medical_warehouse
# 2026-02-17 15:41:31,982 - INFO - 📊 Read 2950 records from local files.
# 2026-02-17 15:41:32,070 - INFO - 📂 Schema 'raw' verified.
# 2026-02-17 15:41:32,327 - INFO - ✅ Loaded 2950 records into raw.telegram_messages
